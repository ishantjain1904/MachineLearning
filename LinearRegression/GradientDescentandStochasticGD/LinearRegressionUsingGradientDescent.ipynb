# %% [markdown]
# # Linear Regression using Gradient Descent

# %% [markdown]
# In statistics, linear regression is a linear approach to modelling the relationship between a dependent variable and one or more independent variables. Let X be the independent variable and Y be the dependent variable. We will define a linear relationship between these two variables as follows:

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\ishan\Desktop\Datasets\Python datasets\data(LRwithGD).xlsx")

# %%
X = data.iloc[:,0]
Y = data.iloc[:,1]

plt.figure(figsize=(11,6))
plt.scatter(X,Y)
plt.show()

# %%
X1 = np.array(X) 
Y1 = np.array(Y)

X1 = X1.reshape(-1,1)
Y1 = Y1.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.33, random_state=101)
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 9.889415664410055

# %%
m = 0 #slope
c = 0 #constant
L = 0.0001 #learning rate
epoch = 1000 #no of iterations

n = float(len(X)) #no of elements in X

for i in range(epoch):
    Y_pred = m*X+c #current prediction value of y
    D_m = (-2/n)*sum(X*(Y-Y_pred)) #derivative of function E = (1/n) sum(Y-(m*X+c)^2) w.r.t m
    D_c = (-2/n)*sum(Y-Y_pred)     #derivative of function E = (1/n) sum(Y-(m*X+c)^2) w.r.t c
    m = m-L*D_m
    c = c-L*D_c
    
print(m,c)
# Out:
# 1.4796491688889393 0.10148121494753894

# %%
Y_pred = m*X+c

plt.figure(figsize=(12,8))
plt.scatter(X,Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')
